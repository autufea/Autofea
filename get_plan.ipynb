# %%
import glob
import os
import shutil
import subprocess
import math
import json
import re
import threading
import time

from langchain_openai import ChatOpenAI,OpenAI
from langchain_core.prompts import PromptTemplate,ChatPromptTemplate,MessagesPlaceholder
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate

# %%
def plain_parser(Message) -> str:
    return Message.content

summary_code_prompt = PromptTemplate.from_template(
    '''
    {code}
    The above code is calculix code, in which the long and repetitive parts are omitted.
    Task: Please describe the function of this code in plain language. 
    I hope to be able to reproduce this code in this language, so some parameters in the code need to be retained in this description.
    Please describe it in natural, human-like language, not in a way that resembles code. Try to write in one paragraph
    '''
)

generate_code_prompt = PromptTemplate.from_template(
    '''
    {description}
    The above description is about FEA simulation. 
    I hope to write a calculix inp file based on this description. 
    I will provide a part of the code, and you can help me complete the following code. 
    Please note that part of the code I give you is omitted and repeated. 
    This is not the part you need to complete. You only need to return the remaining part.
    {code}
    '''
)
step_plan_gen_prompt = PromptTemplate.from_template(
    '''
    Code:
    {code}
    The above the Code of Calculix FEA simulation. 
    I now want to divide this code into multiple steps. Then give a description of each step.
    Please note that lines at the beginning of the code marked with ** generally provide a simple description of the code, and we consider this as the first step. Then, code blocks starting with an asterisk followed by a keyword, such as *NODE, indicate a segment of code. Typically, a step might contain several code segments. 
    For example, 
    *MATERIAL, NAME=EL
    *ELASTIC
    210000.0, .3
    *DENSITY
    7.8E-9 is considered one step that includes the *MATERIAL, *ELASTIC, and *DENSITY segments. 
    Specifically, sections from *STEP to *END STEP are generally regarded as one step.
    Using JSON format to answer. Do not output anything else except json.
    Output Format:
    {{
        "Step 1":{{
            "Description":<1-3 sentances>,
            "Keywords":["<keyword>","<keyword>","<keyword>",...,],
            "Code blocks": [*MATERIAL,*ELASTIC,*DENSITY]
            }},
        "Step 2":{{
        ...
        }}, 
        ....
    }}
    Note: 1. In the 'Code blocks' field, include all lines starting with an asterisk followed by a keyword from each step. Only include the keyword part before any comma, such as '*MATERIAL' from '*MATERIAL, NAME=EL'.
    2. I hope the description includes many detailed pieces of information from the code in this step, so that I can reconstruct the code through the description.
    3. If multiple code blocks of the same type, like *ELEMENT, are present in one step, the 'Code blocks' field should list each *ELEMENT to reflect their respective occurrences. 
    4. For each step, several keywords need to be summarized to reflect the specific functions of this step. These are not the keywords at the beginning of the code blocks, but the keywords extracted from the description. 
    '''
)
step_plan_gen_prompt2 = PromptTemplate.from_template(
    '''
    Code:
    {code}
    The above the Code of Calculix FEA simulation. 
    I have omitted part of the code block if it was too long.
    I have divided the code into multiple steps. The current task is to write a description for each step.
    Using JSON format to answer. Do not output anything else except json.
    Output Format:
    {{
        "Step 1":{{
            "Description":<1-3 sentances>
            }},
        "Step 2":{{
        ...
        }}, 
        ....
    }}
    '''
)

class llm_agent:
    def __init__(self,prompt,parser):
        gpt_key = ''
        self.agent = prompt|ChatOpenAI(temperature=0,api_key=gpt_key, model="gpt-4o")|parser

    def get_result(self,*args, **kwargs):
        llm_response = self.agent.invoke(kwargs)
        return llm_response

# %%
def compare_float_files(file1, file2, rel_tol=1e-4, abs_tol=1e-6):
    with open(file1, 'r') as f1:
        lines = f1.readlines()
        f1_num = len(lines)
    with open(file2, 'r') as f2:
        lines = f2.readlines()
        f2_num = len(lines)
    if f1_num != f2_num:
        return False, -1
    with open(file1, 'r') as f1, open(file2, 'r') as f2:
        line_num = 0
        for line1, line2 in zip(f1, f2):
            if line1.strip() and line2.strip():
                values1 = line1.split()
                values2 = line2.split()
                for v1, v2 in zip(values1, values2):
                    try:
                        float_v1 = float(v1)
                        float_v2 = float(v2)
                        if not math.isclose(float_v1, float_v2, rel_tol=rel_tol, abs_tol=abs_tol):
                            print(f'Difference found at line {line_num}: {float_v1} != {float_v2}')
                            return False,line_num
                    except ValueError:
                        if v1 != v2:
                            print(f'Difference found at line {line_num}: {v1} != {v2}')
                            return False,line_num
            line_num += 1
        return True,line_num

# %%
starts = {}
material_key_words = ["*DAMPING","*DENSITY","*DEPVAR","*EXPANSION","*ACOUSTIC MEDIUM",
                      "*DEFORMATION PLASTICITY","*USER MATERIAL","*ELASTIC","*EOS","*HYPERELASTIC",
                      "*HYPERFOAM","*HYPOELASTIC","*POROUS ELASTIC","*EOS SHEAR","*FAIL STRAIN",
                      "*FAIL STRESS","*HYSTERESIS","*MULLINS EFFECT","*NO COMPRESSION","*NO TENSION",
                      "*VISCOELASTIC","*BRITTLE CRACKING","*CAP PLASTICITY","*CAST IRON PLASTICITY","*CLAY PLASTICITY",
                      "*CONCRETE","*CONCRETE DAMAGED PLASTICITY","*CRUSHABLE FOAM","*DRUCKER PRAGER","*EOS COMPACTION",
                      "*JOINTED MATERIAL","*MOHR COULOMB","*PLASTIC","*CAP CREEP","*CREEP",
                      "*DRUCKER PRAGER CREEP","*PLASTIC","*RATE DEPENDENT","*SWELLING","*VISCOUS",
                      "*ANNEAL TEMPERATURE","*BRITTLE FAILURE","*CYCLIC HARDENING","*INELASTIC HEAT FRACTION","*ORNL",
                      "*POROUS FAILURE CRITERIA","*POROUS METAL PLASTICITY","*POTENTIAL","*SHEAR FAILURE","*TENSILE FAILURE",
                      "*DAMAGE INITIATION","*DAMAGE EVOLUTION","*DAMAGE STABILIZATION","*CONDUCTIVITY","*HEAT GENERATION",
                      "*LATENT HEAT","*SPECIFIC HEAT","*USER MATERIAL","*GEL","*MOISTURE SWELLING",
                      "*PERMEABILITY","*POROUS BULK MODULI","*SORPTION","*DIELECTRIC","*ELECTRICAL CONDUCTIVITY",
                      "*JOULE HEAT FRACTION","*PIEZOELECTRIC","*DIFFUSIVITY","*SOLUBILITY","*FLUID BULK MODULUS","*FLUID DENSITY",
                      "*FLUID EXPANSION"]
not_keywords =['STEP','END STEP','TYPE']
class calculixInp:
    def __init__(self,name,inp_code) -> None:
        self.name = name
        lines = inp_code.splitlines()
        self.inp_code = inp_code
        self.sections = []
        flag = False
        section_code = ''
        section_codes = []
        omit_codes = []
        section_keywords = {}
        section_start = '*HEADING'
        self.structure_code = ''
        self.other_code =''
        self.omit_code = ''

        flag_in_step = False
        flag_in_material = False

        for line in lines:
            if line.startswith('*') and not line.startswith("**"):
                start = line.split(',')[0].upper().strip()

                sec_lines = section_code.splitlines()
                if len(sec_lines) > 7:
                    section_omit = '\n'.join(sec_lines[:5]+['...']+sec_lines[-2:]) + '\n'
                else:
                    section_omit = '\n'.join(sec_lines) + '\n'

                section_codes.append(section_code)
                omit_codes.append(section_omit)

                section_code = ''

                section_code += (line+'\n')
                
                

                flag_new_step = True
                
                if flag_in_step:
                    flag_new_step = False

                if start == '*STEP':
                    flag_new_step = True
                    flag_in_step = True

                if start == '*END STEP':
                    flag_new_step = False
                    flag_in_step = False
                
                

                if flag_in_material and start in material_key_words: 
                    flag_new_step = False
                
                if flag_in_material and start not in material_key_words: 
                    flag_new_step = True
                    flag_in_material = False

                if start == '*MATERIAL':
                    flag_in_material = True
                    flag_new_step = True

                if not flag_in_step and start == section_start:
                    flag_new_step = False

                if flag_new_step:
                    self.sections.append((section_start,section_codes,omit_codes,section_keywords))
                    section_start = start
                    section_codes = []
                    omit_codes = []
                    section_keywords = {}
                
                keywords = line[1:].split(',')

                for keyword in keywords:
                    key = keyword.upper().split('=')[0].strip()
                    if key not in section_keywords and key not in not_keywords:
                        section_keywords[key] = 0
            else:
                section_code += (line+'\n')

        if section_code not in section_codes:
            section_codes.append(section_code)
            omit_codes.append(section_omit)
        if section_codes!=[]:

            self.sections.append((section_start,section_codes,omit_codes,section_keywords))
    
    def get_len(self):
        result = 0
        for step in self.sections:
            result += len(step[2])
        return result
    def get_omit_code(self):
        result =''
        for step in self.sections:
            for code in step[2]:
                result+=code
        return result
    def get_steps_json(self):
        result = {}
        for i, step in enumerate(self.sections):
            step_num = 'Step '+str(i+1)
            result[step_num] = ''.join(step[2])
        return json.dumps(result,indent=4)
    def get_json(self):
        result = {}
        for i, step in enumerate(self.sections):
            step_num = 'Step '+str(i+1)
            result[step_num] = {}
            result[step_num]['Code'] = ''.join(step[1])
            result[step_num]['Keywords'] = []
            for key in step[3]:
                result[step_num]['Keywords'].append(key)
            result[step_num]['Start'] = step[0]
        return result

# %%
def extract_json_from_string(s):
    ss=s
    while (s!='' and s[0]!='{'):
        s = s[1:]
    while (s!='' and s[-1]!='}'):
        s=s[:-1]
    if s!='':
        try:
            json_data = json.loads(s)
            return json_data
        except json.JSONDecodeError:
            return None
    else:
        print("No JSON object found in the string.")
        return None
def thread_task(output_dir,name,sample,plan_agent,sum_agent):
    if sample.get_len()>30:
        return 
    description = sum_agent.get_result(code = sample.get_omit_code())
    plan = plan_agent.get_result(code  = sample.get_steps_json())
    js_plan =extract_json_from_string(plan)
    if js_plan ==None:
        return 
    js_step = sample.get_json()
    for step in js_step:
        if step in js_plan:
            js_step[step]['Description'] = js_plan[step]['Description']
    with open(os.path.join(output_dir,name[:-3]+'plan'),'w') as fout:
        fout.write(json.dumps(js_step,indent=4))
    with open(os.path.join(output_dir,name[:-3]+'des'),'w') as fout:
        fout.write(description)

# %%
output_dir = 'ccx_dataset'
folder_name = 'ccx'
sum_agent = llm_agent(prompt= summary_code_prompt,parser= plain_parser)
plan_agent = llm_agent(step_plan_gen_prompt2,plain_parser)
inps = glob.glob(os.path.join(folder_name,'*.inp'))
lens =[]
for i,inp in enumerate(inps): 
    # if i>1:
    #     break
    with open(inp,'r') as fin:
        inp_code = fin.read()
        sample = calculixInp(name = os.path.basename(inp), inp_code=inp_code)
        
        thread = threading.Thread(target=thread_task, args=(output_dir,os.path.basename(inp),sample, plan_agent,sum_agent))
        threads.append(thread)
        thread.start()
        if i!=0 and i%25 ==0:
            print(i)
            for thread in threads:
                thread.join(timeout=50)
            threads = []
for thread in threads:
    thread.join(timeout=50)
# Out:
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250
# 275
# 300
# 325
# 350
# 375
# 400
# 425
# 450
# 475
# 500
# 525
# 550
# 575

# %%
output_dir = 'ccx_dataset'
folder_name = 'ccx'
inps = glob.glob(os.path.join(output_dir,'*.plan'))
print(len(inps))

for i,inp in enumerate(inps): 
    print(inp)
    with open(os.path.join(folder_name,os.path.basename(inp)[:-4]+'inp'),'r') as fin:
        code = fin.read()
        with open(os.path.join(output_dir,os.path.basename(inp)[:-4]+'inp'),'w')  as fout:
            fout.write(code)
    with open(os.path.join(folder_name,os.path.basename(inp)[:-4]+'dat.ref'),'r') as fin:
        code = fin.read()
        with open(os.path.join(output_dir,os.path.basename(inp)[:-4]+'dat.ref'),'w')  as fout:
            fout.write(code)
# Out:
# 528
# ccx_dataset/artery2.plan
# ccx_dataset/cou2d.plan
# ccx_dataset/beamnlptp.plan
# ccx_dataset/disconnect.plan
# ccx_dataset/beamimpdy1nodirect.plan
# ccx_dataset/beamd3.plan
# ccx_dataset/contact11.plan
# ccx_dataset/segdyn.plan
# ccx_dataset/networkmpc2.plan
# ccx_dataset/beamb.plan
# ccx_dataset/beamog.plan
# ccx_dataset/beamdy6.plan
# ccx_dataset/beamfsuper.plan
# ccx_dataset/channeljoint1.plan
# ccx_dataset/gaspipe-cfd-pressure.plan
# ccx_dataset/sens_freq_orien.plan
# ccx_dataset/solidshell2.plan
# ccx_dataset/substructure.plan
# ccx_dataset/pipempc1.plan
# ccx_dataset/beamptied1noadjust.plan
# ccx_dataset/beamf.plan
# ccx_dataset/sens3d.plan
# ccx_dataset/membrane2.plan
# ccx_dataset/beamdy4.plan
# ccx_dataset/beamprand.plan
# ccx_dataset/acou1.plan
# ccx_dataset/lin_stat_th_gradient.plan
# ccx_dataset/acou4.plan
# ccx_dataset/beamdy5.plan
# ccx_dataset/beamdy12.plan
# ccx_dataset/oneel20cf.plan
# ccx_dataset/ring4.plan
# ccx_dataset/channel14a.plan
# ccx_dataset/cubenewt.plan
# ccx_dataset/potied.plan
# ccx_dataset/contact9.plan
# ccx_dataset/beamdelay.plan
# ccx_dataset/shell2.plan
# ccx_dataset/spring7.plan
# ccx_dataset/coupling14.plan
# ccx_dataset/segment1.plan
# ccx_dataset/resstress2.plan
# ccx_dataset/beamnldyp.plan
# ccx_dataset/gaspipe1-oil.plan
# ccx_dataset/membrane3.plan
# ccx_dataset/labyrinth1fin.plan
# ccx_dataset/beamdy1.plan
# ccx_dataset/gaspipe12.plan
# ccx_dataset/segmentmass.plan
# ccx_dataset/unetp1.plan
# ccx_dataset/networkmpc.plan
# ccx_dataset/coucylcentcomp.plan
# ccx_dataset/planestress2.plan
# ccx_dataset/axial.plan
# ccx_dataset/coucylcent2.plan
# ccx_dataset/rot2.plan
# ccx_dataset/beamwrite2.plan
# ccx_dataset/segmentf.plan
# ccx_dataset/slant.plan
# ccx_dataset/linearnet.plan
# ccx_dataset/shell3.plan
# ccx_dataset/beampset.plan
# ccx_dataset/beamdynamic2.plan
# ccx_dataset/gaspipe7.plan
# ccx_dataset/labyrinthstraight.plan
# ccx_dataset/hinge.plan
# ccx_dataset/plate2dpeeq.plan
# ccx_dataset/beamft.plan
# ccx_dataset/contact17.plan
# ccx_dataset/beamhtbf.plan
# ccx_dataset/beamrb2.plan
# ccx_dataset/shell7rot.plan
# ccx_dataset/concretebeam.plan
# ccx_dataset/rot1.plan
# ccx_dataset/coupling3.plan
# ccx_dataset/beamdy18.plan
# ccx_dataset/channel3.plan
# ccx_dataset/segmenttet.plan
# ccx_dataset/gaspipe1.plan
# ccx_dataset/rotpipe2.plan
# ccx_dataset/channel2a.plan
# ccx_dataset/beamnh.plan
# ccx_dataset/pret2.plan
# ccx_dataset/beam20t.plan
# ccx_dataset/beamdy15.plan
# ccx_dataset/contactenergy.plan
# ccx_dataset/beamcom.plan
# ccx_dataset/mass1.plan
# ccx_dataset/branchjoint1.plan
# ccx_dataset/gaspipe8-oil.plan
# ccx_dataset/beamnldype.plan
# ccx_dataset/crackIIcumhcf2.plan
# ccx_dataset/largerot3.plan
# ccx_dataset/leifer2.plan
# ccx_dataset/coupling11.plan
# ccx_dataset/primaryair.plan
# ccx_dataset/beammix.plan
# ccx_dataset/beamnoan.plan
# ccx_dataset/cube2.plan
# ccx_dataset/cubef2f1.plan
# ccx_dataset/pret4.plan
# ccx_dataset/equrem3.plan
# ccx_dataset/substructure2.plan
# ccx_dataset/rotpipe6.plan
# ccx_dataset/channeljoint2.plan
# ccx_dataset/oneel20rs.plan
# ccx_dataset/beamnldy.plan
# ccx_dataset/testmortar.plan
# ccx_dataset/sens_disp_orien_nlgeom.plan
# ccx_dataset/beamhtfcnu.plan
# ccx_dataset/channel12.plan
# ccx_dataset/coupling6.plan
# ccx_dataset/beamnldye2.plan
# ccx_dataset/contact16.plan
# ccx_dataset/beamnlmpc.plan
# ccx_dataset/beamhtfcaerothne.plan
# ccx_dataset/beamptied2.plan
# ccx_dataset/segmentface.plan
# ccx_dataset/coupling7.plan
# ccx_dataset/beamimpdy2.plan
# ccx_dataset/scheibejc.plan
# ccx_dataset/beamdy10.plan
# ccx_dataset/poi2dturb.plan
# ccx_dataset/opt1dp.plan
# ccx_dataset/coupling2.plan
# ccx_dataset/opt1.plan
# ccx_dataset/sens_disp_orien.plan
# ccx_dataset/centheat1.plan
# ccx_dataset/channel13.plan
# ccx_dataset/shell4.plan
# ccx_dataset/characteristic.plan
# ccx_dataset/ax6.plan
# ccx_dataset/beamt.plan
# ccx_dataset/beamd.plan
# ccx_dataset/channel16.plan
# ccx_dataset/pipe2.plan
# ccx_dataset/beam_sens_stress_coord1.plan
# ccx_dataset/shell1.plan
# ccx_dataset/ax6ht.plan
# ccx_dataset/channel9.plan
# ccx_dataset/acou2.plan
# ccx_dataset/edgeload.plan
# ccx_dataset/contact6.plan
# ccx_dataset/beam10psmooth.plan
# ccx_dataset/gaspipe8-cfd-pressure-split.plan
# ccx_dataset/pendel.plan
# ccx_dataset/beamt6.plan
# ccx_dataset/labyrinthstepped.plan
# ccx_dataset/leifer1.plan
# ccx_dataset/pret3.plan
# ccx_dataset/achtel9.plan
# ccx_dataset/shellnor.plan
# ccx_dataset/submodeltwobeamnlgeom.plan
# ccx_dataset/opt3.plan
# ccx_dataset/beampfix.plan
# ccx_dataset/rotpipe3.plan
# ccx_dataset/channel15.plan
# ccx_dataset/beamptied4.plan
# ccx_dataset/small_pressure_gradient.plan
# ccx_dataset/uprofile.plan
# ccx_dataset/dashpot2.plan
# ccx_dataset/contact13.plan
# ccx_dataset/simplebeampipe3.plan
# ccx_dataset/modelchel2.plan
# ccx_dataset/beamabq.plan
# ccx_dataset/beamread3.plan
# ccx_dataset/artery4.plan
# ccx_dataset/rotpipe5.plan
# ccx_dataset/beamnld.plan
# ccx_dataset/planestress3dsens.plan
# ccx_dataset/beamt2.plan
# ccx_dataset/rotpipe3inv.plan
# ccx_dataset/beamdynamic.plan
# ccx_dataset/beamnldyems.plan
# ccx_dataset/beamhf.plan
# ccx_dataset/channelcbs.plan
# ccx_dataset/mpcforce.plan
# ccx_dataset/beamdy16.plan
# ccx_dataset/beamidset.plan
# ccx_dataset/artery3.plan
# ccx_dataset/largerot5.plan
# ccx_dataset/beamp1rotate.plan
# ccx_dataset/branchjoint2.plan
# ccx_dataset/beamt3.plan
# ccx_dataset/oneel20fi2.plan
# ccx_dataset/crossley6.plan
# ccx_dataset/beampo4.plan
# ccx_dataset/beamnldye20.plan
# ccx_dataset/green4.plan
# ccx_dataset/beammr.plan
# ccx_dataset/b31nodthi.plan
# ccx_dataset/beamlin.plan
# ccx_dataset/pret5.plan
# ccx_dataset/beammpc.plan
# ccx_dataset/cubespring.plan
# ccx_dataset/dashpot3.plan
# ccx_dataset/beamf4.plan
# ccx_dataset/dyncubeexp.plan
# ccx_dataset/truss.plan
# ccx_dataset/beamth.plan
# ccx_dataset/couseg3.plan
# ccx_dataset/beamexpdy1.plan
# ccx_dataset/beamabqnl.plan
# ccx_dataset/branchjoint3.plan
# ccx_dataset/beamdy3.plan
# ccx_dataset/circ10pcent.plan
# ccx_dataset/beamd2.plan
# ccx_dataset/couseg2.plan
# ccx_dataset/shellf2.plan
# ccx_dataset/sensitivity_I.plan
# ccx_dataset/segmentm.plan
# ccx_dataset/coupling9.plan
# ccx_dataset/gaspipe8-cfd-massflow.plan
# ccx_dataset/gaspipe5.plan
# ccx_dataset/beamstraight.plan
# ccx_dataset/beampo2.plan
# ccx_dataset/beamdy7bm.plan
# ccx_dataset/beam20p.plan
# ccx_dataset/contact14.plan
# ccx_dataset/cubeslinmortar.plan
# ccx_dataset/branchjoint4.plan
# ccx_dataset/vortex2.plan
# ccx_dataset/branchsplit3.plan
# ccx_dataset/ball.plan
# ccx_dataset/gaspipe6.plan
# ccx_dataset/segmentsmooth2.plan
# ccx_dataset/beam_sens_freq_coord2.plan
# ccx_dataset/spring6.plan
# ccx_dataset/planestrain2.plan
# ccx_dataset/spring3.plan
# ccx_dataset/segmentnum.plan
# ccx_dataset/beamplane.plan
# ccx_dataset/contact10.plan
# ccx_dataset/coupling8.plan
# ccx_dataset/sensitivity_VII.plan
# ccx_dataset/contact15lin.plan
# ccx_dataset/beammrlin.plan
# ccx_dataset/beamrb.plan
# ccx_dataset/cubef2f2.plan
# ccx_dataset/beampo3.plan
# ccx_dataset/gaspipe2.plan
# ccx_dataset/beamnlp.plan
# ccx_dataset/aircolumn.plan
# ccx_dataset/beamread2.plan
# ccx_dataset/beamprb.plan
# ccx_dataset/achtelc.plan
# ccx_dataset/beampo5.plan
# ccx_dataset/beamp_ciarlet.plan
# ccx_dataset/punch1.plan
# ccx_dataset/shell7rot2.plan
# ccx_dataset/plate2dmass.plan
# ccx_dataset/simplebeampipe1.plan
# ccx_dataset/pipempc2.plan
# ccx_dataset/beamhtcr.plan
# ccx_dataset/wire.plan
# ccx_dataset/channel5.plan
# ccx_dataset/rot3.plan
# ccx_dataset/beamdy8.plan
# ccx_dataset/dyncube.plan
# ccx_dataset/anipla.plan
# ccx_dataset/simplebeampipe4.plan
# ccx_dataset/sc123.plan
# ccx_dataset/tempdiscon.plan
# ccx_dataset/boxprofile2.plan
# ccx_dataset/beamp.plan
# ccx_dataset/dloadlinIf.plan
# ccx_dataset/beam_sens_stress_coord2.plan
# ccx_dataset/b31.plan
# ccx_dataset/pipempc3.plan
# ccx_dataset/beamdy9.plan
# ccx_dataset/segmentsuper.plan
# ccx_dataset/largerot1.plan
# ccx_dataset/beam10p.plan
# ccx_dataset/gaspipe4.plan
# ccx_dataset/beamhtfcaero.plan
# ccx_dataset/beamdy14.plan
# ccx_dataset/greencyc1.plan
# ccx_dataset/shell5.plan
# ccx_dataset/shell6rot2.plan
# ccx_dataset/spring5.plan
# ccx_dataset/contact4_mortar.plan
# ccx_dataset/beamdy13.plan
# ccx_dataset/beamread4.plan
# ccx_dataset/vortex1.plan
# ccx_dataset/solidshell1.plan
# ccx_dataset/gaspipe8.plan
# ccx_dataset/coupling13.plan
# ccx_dataset/resstress1.plan
# ccx_dataset/beammrco.plan
# ccx_dataset/chanson1.plan
# ccx_dataset/ring2.plan
# ccx_dataset/simplebeampipe2.plan
# ccx_dataset/dashpot1.plan
# ccx_dataset/beamptied7.plan
# ccx_dataset/crackIIcum.plan
# ccx_dataset/green2.plan
# ccx_dataset/channel8.plan
# ccx_dataset/oneeltruss.plan
# ccx_dataset/segment2.plan
# ccx_dataset/sc123creep.plan
# ccx_dataset/circ10p.plan
# ccx_dataset/equrem1.plan
# ccx_dataset/contact5.plan
# ccx_dataset/beampd.plan
# ccx_dataset/equrem2.plan
# ccx_dataset/channel7.plan
# ccx_dataset/contact15.plan
# ccx_dataset/beamfsh1.plan
# ccx_dataset/spring1.plan
# ccx_dataset/green3.plan
# ccx_dataset/gaspipe-fanno8-oil.plan
# ccx_dataset/beamhtfc.plan
# ccx_dataset/gaspipe11.plan
# ccx_dataset/userbeam2.plan
# ccx_dataset/largerot4.plan
# ccx_dataset/unet1.plan
# ccx_dataset/dashpot5.plan
# ccx_dataset/segmentbeam2.plan
# ccx_dataset/vortex3.plan
# ccx_dataset/beamtor.plan
# ccx_dataset/shellbeam.plan
# ccx_dataset/inistrain2.plan
# ccx_dataset/channel4.plan
# ccx_dataset/axrad.plan
# ccx_dataset/swing.plan
# ccx_dataset/section.plan
# ccx_dataset/freq_test.plan
# ccx_dataset/dist.plan
# ccx_dataset/channel2.plan
# ccx_dataset/pret1.plan
# ccx_dataset/dloadlin20f.plan
# ccx_dataset/submodelbeamp.plan
# ccx_dataset/rotor3.plan
# ccx_dataset/channel1.plan
# ccx_dataset/segmenttemp.plan
# ccx_dataset/beamhtcr2.plan
# ccx_dataset/zerovel.plan
# ccx_dataset/distcoupspring.plan
# ccx_dataset/gaspipe15.plan
# ccx_dataset/beampisof.plan
# ccx_dataset/boxprofile.plan
# ccx_dataset/artery5.plan
# ccx_dataset/beam_sens_freq_coord1.plan
# ccx_dataset/shell6.plan
# ccx_dataset/contact8.plan
# ccx_dataset/beamt4.plan
# ccx_dataset/coupling10.plan
# ccx_dataset/mass3.plan
# ccx_dataset/oneel.plan
# ccx_dataset/changesolidsection.plan
# ccx_dataset/beamdy17.plan
# ccx_dataset/equrem4.plan
# ccx_dataset/beamnldyeortho.plan
# ccx_dataset/beamb2.plan
# ccx_dataset/acou5.plan
# ccx_dataset/axiplane.plan
# ccx_dataset/capacitor.plan
# ccx_dataset/planestrain.plan
# ccx_dataset/sens_freq_disp_cyc.plan
# ccx_dataset/beamf3.plan
# ccx_dataset/mohr2.plan
# ccx_dataset/changecontacttype1.plan
# ccx_dataset/largerot7.plan
# ccx_dataset/achtelcas.plan
# ccx_dataset/aniso.plan
# ccx_dataset/coucylcomp.plan
# ccx_dataset/segmentunsmooth.plan
# ccx_dataset/moehring.plan
# ccx_dataset/plate2dfeasdir.plan
# ccx_dataset/oneel20df2.plan
# ccx_dataset/beamdy11.plan
# ccx_dataset/contact12.plan
# ccx_dataset/beamu.plan
# ccx_dataset/mohr1.plan
# ccx_dataset/beam_sens_ps13.plan
# ccx_dataset/coucylcent.plan
# ccx_dataset/beamptied5.plan
# ccx_dataset/channeljoint1a.plan
# ccx_dataset/beamhtbo.plan
# ccx_dataset/beampl.plan
# ccx_dataset/segststate.plan
# ccx_dataset/segmentsmooth.plan
# ccx_dataset/carbonseal.plan
# ccx_dataset/oneel20df.plan
# ccx_dataset/beamf2.plan
# ccx_dataset/massflow_percent_ccx.plan
# ccx_dataset/beamfstrucdamp.plan
# ccx_dataset/branch1.plan
# ccx_dataset/truss2.plan
# ccx_dataset/beampt.plan
# ccx_dataset/sens_modalstress.plan
# ccx_dataset/beamperror.plan
# ccx_dataset/cyl.plan
# ccx_dataset/beampdepmpc.plan
# ccx_dataset/bifur.plan
# ccx_dataset/beamdy20.plan
# ccx_dataset/gaspipe3.plan
# ccx_dataset/lin_stat_pres_load.plan
# ccx_dataset/rotor2.plan
# ccx_dataset/ring3.plan
# ccx_dataset/beampsuper.plan
# ccx_dataset/beamdy10bm.plan
# ccx_dataset/induction.plan
# ccx_dataset/shell1lin.plan
# ccx_dataset/channel14.plan
# ccx_dataset/lin_stat_cooks_beam_128.plan
# ccx_dataset/sensitivity_V.plan
# ccx_dataset/simplebeam.plan
# ccx_dataset/planestress3.plan
# ccx_dataset/contact7.plan
# ccx_dataset/inistrain.plan
# ccx_dataset/dloadlinI.plan
# ccx_dataset/beamwrite.plan
# ccx_dataset/resstress3.plan
# ccx_dataset/beamcontact.plan
# ccx_dataset/segmentbeam.plan
# ccx_dataset/gaspipe8-cfd-pressure.plan
# ccx_dataset/dam.plan
# ccx_dataset/load1.plan
# ccx_dataset/lin_stat_twisted_beam.plan
# ccx_dataset/gaspipe-fanno10.plan
# ccx_dataset/oneel20fi3.plan
# ccx_dataset/beamcr.plan
# ccx_dataset/transition.plan
# ccx_dataset/coupling12.plan
# ccx_dataset/beamnldye.plan
# ccx_dataset/shell7.plan
# ccx_dataset/planestress.plan
# ccx_dataset/simplebeampipe5.plan
# ccx_dataset/pret7.plan
# ccx_dataset/changesurfbeh.plan
# ccx_dataset/coupling1.plan
# ccx_dataset/beamfsubmodel.plan
# ccx_dataset/segment.plan
# ccx_dataset/beam_sens_freq_coord3.plan
# ccx_dataset/membrane1.plan
# ccx_dataset/changecontacttype2.plan
# ccx_dataset/rotpipe1.plan
# ccx_dataset/branchsplit2.plan
# ccx_dataset/gaspipe9.plan
# ccx_dataset/section4.plan
# ccx_dataset/beamimpdy1.plan
# ccx_dataset/modelchel.plan
# ccx_dataset/beamfrdread.plan
# ccx_dataset/beamheatplas.plan
# ccx_dataset/branch2.plan
# ccx_dataset/distcoup.plan
# ccx_dataset/submodeltwobeam.plan
# ccx_dataset/fullseg.plan
# ccx_dataset/beampis.plan
# ccx_dataset/spring4.plan
# ccx_dataset/cubesmortar.plan
# ccx_dataset/beamp2rotate.plan
# ccx_dataset/beamf3submodel.plan
# ccx_dataset/rot4.plan
# ccx_dataset/lin_stat_initial_temp_condition.plan
# ccx_dataset/plate.plan
# ccx_dataset/achtelp.plan
# ccx_dataset/artery1.plan
# ccx_dataset/contact3.plan
# ccx_dataset/crackIIcumhcf.plan
# ccx_dataset/planestress4.plan
# ccx_dataset/beampo6.plan
# ccx_dataset/largerot2.plan
# ccx_dataset/rotor.plan
# ccx_dataset/sensitivity_VI.plan
# ccx_dataset/beamnlt.plan
# ccx_dataset/rotpipe7.plan
# ccx_dataset/beamuamp.plan
# ccx_dataset/dashpot6.plan
# ccx_dataset/rotpipeu.plan
# ccx_dataset/beamwrite3.plan
# ccx_dataset/oneel8ra.plan
# ccx_dataset/beamhtfc2.plan
# ccx_dataset/contact1.plan
# ccx_dataset/beamptied6.plan
# ccx_dataset/oneel20fi.plan
# ccx_dataset/beamptrans.plan
# ccx_dataset/rotpipe4.plan
# ccx_dataset/gap.plan
# ccx_dataset/green1.plan
# ccx_dataset/pret6.plan
# ccx_dataset/c3d6.plan
# ccx_dataset/beamp2stage.plan
# ccx_dataset/submodelbeampdouble.plan
# ccx_dataset/beamp2.plan
# ccx_dataset/channel10.plan
# ccx_dataset/beamnldynodirect.plan
# ccx_dataset/contact18.plan
# ccx_dataset/beamdy10dd.plan
# ccx_dataset/beamptied1.plan
# ccx_dataset/userbeam.plan
# ccx_dataset/ring1.plan
# ccx_dataset/channel6.plan
# ccx_dataset/punch2.plan
# ccx_dataset/beamread.plan
# ccx_dataset/cubes.plan
# ccx_dataset/channel11.plan
# ccx_dataset/achtelg.plan
# ccx_dataset/contact4.plan
# ccx_dataset/square.plan
# ccx_dataset/scheibe.plan
# ccx_dataset/cubespglinmortar.plan
# ccx_dataset/mass2.plan
# ccx_dataset/friction1.plan
# ccx_dataset/distcoup2.plan
# ccx_dataset/gaspres.plan
# ccx_dataset/achteld.plan
# ccx_dataset/c3d15.plan
# ccx_dataset/beamcr2.plan
# ccx_dataset/crackIIint.plan
# ccx_dataset/channeljoint3.plan
# ccx_dataset/shellf.plan
# ccx_dataset/branchsplit1.plan
# ccx_dataset/gaspipe14.plan
# ccx_dataset/acouquad.plan
# ccx_dataset/gap2.plan
# ccx_dataset/gaspipe13.plan
# ccx_dataset/cubef2f3.plan
# ccx_dataset/achtel29.plan
# ccx_dataset/beamdy2.plan
# ccx_dataset/beampic.plan
# ccx_dataset/achtel2.plan
# ccx_dataset/beampo1.plan
# ccx_dataset/beamdy7.plan
# ccx_dataset/beampsuper2.plan
# ccx_dataset/acou3.plan
# ccx_dataset/spring2.plan
